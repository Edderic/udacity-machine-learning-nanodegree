# %%
import pandas
import numpy

# %%
numpy.average([1, 2])
# Out:
# 1.5

# %%
numpy.std([1, 2])
# Out:
# 0.5

# %%
df = pandas.DataFrame.from_csv('alpha_gamma_experiments.csv')
df
# Out:
#     alpha  avg_total_actions  avg_total_rewards  gamma  std_total_actions  \
# 0     0.1             1275.8             2870.2    0.1          49.746960
# 1     0.1             1259.4             2853.7    0.3          62.121172
# 2     0.1             1272.2             2868.5    0.7          72.755481
# 3     0.1             1276.2             2867.9    0.9          53.966286
# 4     0.3             1276.6             2866.9    0.1          30.604575
# 5     0.3             1290.6             2883.6    0.3          67.486591
# 6     0.3             1252.1             2831.8    0.7          54.784031
# 7     0.3             1285.8             2881.0    0.9          70.455376
# 8     0.7             1340.5             2942.5    0.1          51.761472
# 9     0.7             1248.8             2836.9    0.3          28.049242
# 10    0.7             1256.5             2846.1    0.7          48.276806
# 11    0.7             1270.1             2863.3    0.9          43.882685
# ...

# %%
df['reward_per_action'] = df['avg_total_rewards'] / df['avg_total_actions']

# %%
df
# Out:
#     alpha  avg_total_actions  avg_total_rewards  gamma  std_total_actions  \
# 0     0.1             1275.8             2870.2    0.1          49.746960
# 1     0.1             1259.4             2853.7    0.3          62.121172
# 2     0.1             1272.2             2868.5    0.7          72.755481
# 3     0.1             1276.2             2867.9    0.9          53.966286
# 4     0.3             1276.6             2866.9    0.1          30.604575
# 5     0.3             1290.6             2883.6    0.3          67.486591
# 6     0.3             1252.1             2831.8    0.7          54.784031
# 7     0.3             1285.8             2881.0    0.9          70.455376
# 8     0.7             1340.5             2942.5    0.1          51.761472
# 9     0.7             1248.8             2836.9    0.3          28.049242
# 10    0.7             1256.5             2846.1    0.7          48.276806
# 11    0.7             1270.1             2863.3    0.9          43.882685
# ...
